# %%
# 필요한 라이브러리 임포트
from binance.client import Client
from binance.enums import *
import pandas as pd
from datetime import datetime , timedelta
import time

import pandas as pd
import numpy as np
import torch
import pyarrow

# %%
# API 키 설정
api_key = ''
api_secret = ''

# 바이낸스 클라이언트 초기화
client = Client(api_key, api_secret)

# %%
class Future_db:
    def __init__(self):
        self.futures = None
        self.curent_symbols = self.get_all_futures_symbols()
        self.top10_futures = None
    
    def get_futures_klines(self, symbol='BTCUSDT', interval='30m', limit=500):
        """
        선물 캔들스틱 데이터 가져오기
        :param symbol: 거래쌍 (예: 'BTCUSDT')
        :param interval: 시간간격 (1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w, 1M)
        :param limit: 가져올 캔들 수
        :return: DataFrame
        """
        try:
            klines = client.futures_klines(symbol=symbol, interval=interval, limit=limit)
            
            # DataFrame 생성
            df = pd.DataFrame(klines, columns=['timestamp', 'open', 'high', 'low', 'close', 
                                            'volume', 'close_time', 'quote_volume', 'trades',
                                            'taker_base', 'taker_quote', 'ignore'])
            
            # 데이터 타입 변환
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
            for col in ['open', 'high', 'low', 'close', 'volume', 'quote_volume']:
                df[col] = df[col].astype(float)
                
            return df[['timestamp', 'open', 'high', 'low', 'close', 'volume', 'quote_volume']]
        
        except Exception as e:
            print(f"에러 발생: {e}")
            return None

    def get_futures_position(self, symbol='BTCUSDT'):
        """
        현재 선물 포지션 정보 가져오기
        :param symbol: 거래쌍
        :return: Dictionary
        """
        try:
            position = client.futures_position_information(symbol=symbol)
            return position
        except Exception as e:
            print(f"에러 발생: {e}")
            return None

    def get_all_futures_symbols(self):
        """
        거래 가능한 모든 선물 심볼 목록 반환
        """
        try:
            exchange_info = client.futures_exchange_info()
            return [symbol['symbol'] for symbol in exchange_info['symbols'] if symbol['status'] == 'TRADING']
        except Exception as e:
            print(f"심볼 목록 조회 에러: {e}")
            return None

    def get_futures_historical_klines(self, symbol='BTCUSDT', interval='30m', start_str='2017-01-01', end_str='2025-04-09'):
        """
        특정 기간의 선물 캔들스틱 데이터 가져오기
        :param symbol: 거래쌍 또는 'all'
        :param interval: 시간간격
        :param start_str: 시작 날짜 (YYYY-MM-DD)
        :param end_str: 종료 날짜 (YYYY-MM-DD)
        :return: Dictionary of DataFrames (symbol을 'all'로 지정한 경우) 또는 단일 DataFrame
        """
        try:
            # 날짜를 타임스탬프로 변환
            start_ts = int(pd.Timestamp(start_str).timestamp() * 1000)
            end_ts = int(pd.Timestamp(end_str).timestamp() * 1000)

            if symbol.lower() == 'all':
                symbols = get_all_futures_symbols()
                if not symbols:
                    return None
                
                result = {}
                for sym in symbols:
                    print(f"{sym} 데이터 수집 중...")
                    klines = []
                    while start_ts < end_ts:
                        temp_data = client.futures_historical_klines(
                            symbol=sym,
                            interval=interval,
                            start_str=str(start_ts),
                            end_str=str(end_ts),
                            limit=1000
                        )
                        if not temp_data:
                            break
                        klines.extend(temp_data)
                        start_ts = temp_data[-1][0] + 1  # 다음 시작점을 마지막 데이터의 다음 시점으로 설정
                        time.sleep(0.1)  # API 호출 제한 방지
                    
                    if klines:
                        df = pd.DataFrame(klines, columns=['timestamp', 'open', 'high', 'low', 'close', 
                                                        'volume', 'close_time', 'quote_volume', 'trades',
                                                        'taker_base', 'taker_quote', 'ignore'])
                        df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
                        for col in ['open', 'high', 'low', 'close', 'volume', 'quote_volume']:
                            df[col] = df[col].astype(float)
                        result[sym] = df[['timestamp', 'open', 'high', 'low', 'close', 'volume', 'quote_volume']]
                    time.sleep(0.5)
                return result
            
            else:
                klines = []
                while start_ts < end_ts:
                    temp_data = client.futures_historical_klines(
                        symbol=symbol,
                        interval=interval,
                        start_str=str(start_ts),
                        end_str=str(end_ts),
                        limit=1000
                    )
                    if not temp_data:
                        break
                    klines.extend(temp_data)
                    start_ts = temp_data[-1][0] + 1  # 다음 시작점을 마지막 데이터의 다음 시점으로 설정
                    time.sleep(0.1)  # API 호출 제한 방지
                
                df = pd.DataFrame(klines, columns=['timestamp', 'open', 'high', 'low', 'close', 
                                                'volume', 'close_time', 'quote_volume', 'trades',
                                                'taker_base', 'taker_quote', 'ignore'])
                
                df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
                for col in ['open', 'high', 'low', 'close', 'volume', 'quote_volume']:
                    df[col] = df[col].astype(float)
                    
                return df[['timestamp', 'open', 'high', 'low', 'close', 'volume']]
        
        except Exception as e:
            print(f"에러 발생: {e}")
            return None
    def get_market_cap_rank(self, start_date = None, end_date = None, ranges = None):
        """
        start_date : 시작 날짜 
        end_date = 종료 날짜 
        ranges = 심볼 범위 지정
        """
        if self.curent_symbols is None:
            symbols = get_all_futures_symbols()
        else:
            symbols = self.curent_symbols
        
        if ranges is not None:
            symbols = symbols[:ranges]

        # 기준: 전날 날짜 기준 한달 전부터
        if start_date is None and end_date is None:
            today = datetime.now().date()
            end_date = today - timedelta(days=1)
            start_date = end_date - timedelta(days=30)
        else:
            start_date = datetime.strptime(start_date, "%Y-%m-%d")
            end_date  = datetime.strptime(end_date, "%Y-%m-%d")
        print(f"데이터 수집 기간: {start_date} ~ {end_date}")

        results = []

        for i, symbol in enumerate(symbols):
            print(f"[{i+1}/{len(symbols)}] {symbol} 처리 중...")

            try:
                df = self.get_futures_historical_klines(
                    symbol=symbol,
                    interval='1d',
                    start_str=start_date.strftime('%Y-%m-%d'),
                    end_str=end_date.strftime('%Y-%m-%d')
                )

                if df is None or df.empty:
                    continue

                avg_price = df['close'].mean()
                avg_volume = df['volume'].mean()
                market_cap = avg_price * avg_volume

                results.append({
                    'symbol': symbol,
                    'avg_price': avg_price,
                    'avg_volume': avg_volume,
                    'market_cap': market_cap
                })

                time.sleep(0.2)  # API 제한 방지
            except Exception as e:
                print(f"{symbol} 처리 중 에러 발생: {e}")
                continue

        # 정렬
        df_result = pd.DataFrame(results)
        df_result = df_result.sort_values(by='market_cap', ascending=False).reset_index(drop=True)

        return df_result

    def get_top10_futures(self, interval = '30m',symbols_option=1, symobls_list = None):
        """시가총액 기준 상위 10개 선물 종목을 반환합니다.
        
        (self, symbols_option=1, symobls_list == None)

        Param

        interval = '30m'  : 시간간격 (1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w, 1M)
        symbols_option==1 : api에서 받은 심볼을 슬라이싱 합니다.
        symbols_option==2 : 현재로부터 한달전의 마켓 켑을 두고, 약 422개를 계산한 후 10를 선별합니다.
        symbols_option==3 : 임의로 지정한 symbols_list 를 심볼로 사용합니다.(날짜를 변경할 때 사용)
            symobls_list: 심볼리스트를 지정해서 데이터를 가져옵니다.(option 3와 함꼐사용)
        """
        if symbols_option == 1:
            symbols = self.curent_symbols[:10]
        elif symbols_option ==2:
            symbols_marketcap = self.get_market_cap_rank()
            symbols = list(symbols_marketcap['symbol'][:10])
        elif symbols_option == 3:
            symbols = symobls_list
        dfs = []

        for i, symbol in enumerate(symbols):
            print(f"[{i+1}/{len(symbols)}] {symbol} 처리 중...")
            tmp = self.get_futures_historical_klines(
                symbol=symbol,
                interval='30m',
                end_str=datetime.now().strftime('%Y-%m-%d')
            )

            if tmp is None or tmp.empty:
                continue

            # 'timestamp'를 인덱스로 하고, 'close'만 추출해서 컬럼명 바꾸기
            close_series = tmp.set_index('timestamp')['close'].rename(symbol)
            dfs.append(close_series)

        merged_df = pd.concat(dfs, axis=1)
        merged_df = merged_df.sort_index().reset_index()  # timestamp 복원
        merged_df.set_index('timestamp', inplace=True)
        return merged_df

# %%
#class 객체 생성
futures = Future_db()

# %%
#심볼 확인
symbols_marketcap = futures.get_market_cap_rank(start_date='2024-03-08', end_date='2024-04-07')
symbols_marketcap
# Out:
# 데이터 수집 기간: 2024-03-08 00:00:00 ~ 2024-04-07 00:00:00
# [1/423] BTCUSDT 처리 중...
# [2/423] ETHUSDT 처리 중...
# [3/423] BCHUSDT 처리 중...
# [4/423] XRPUSDT 처리 중...
# [5/423] EOSUSDT 처리 중...
# [6/423] LTCUSDT 처리 중...
# [7/423] TRXUSDT 처리 중...
# [8/423] ETCUSDT 처리 중...
# [9/423] LINKUSDT 처리 중...
# [10/423] XLMUSDT 처리 중...
# [11/423] ADAUSDT 처리 중...
# [12/423] XMRUSDT 처리 중...
# [13/423] DASHUSDT 처리 중...
# [14/423] ZECUSDT 처리 중...
# [15/423] XTZUSDT 처리 중...
# [16/423] BNBUSDT 처리 중...
# [17/423] ATOMUSDT 처리 중...
# [18/423] ONTUSDT 처리 중...
# [19/423] IOTAUSDT 처리 중...
# [20/423] BATUSDT 처리 중...
# [21/423] VETUSDT 처리 중...
# [22/423] NEOUSDT 처리 중...
# [23/423] QTUMUSDT 처리 중...
# [24/423] IOSTUSDT 처리 중...
# [25/423] THETAUSDT 처리 중...
# [26/423] ALGOUSDT 처리 중...
# [27/423] ZILUSDT 처리 중...
# [28/423] KNCUSDT 처리 중...
# [29/423] ZRXUSDT 처리 중...
# [30/423] COMPUSDT 처리 중...
# [31/423] DOGEUSDT 처리 중...
# [32/423] SXPUSDT 처리 중...
# [33/423] KAVAUSDT 처리 중...
# [34/423] BANDUSDT 처리 중...
# [35/423] RLCUSDT 처리 중...
# [36/423] MKRUSDT 처리 중...
# [37/423] SNXUSDT 처리 중...
# [38/423] DOTUSDT 처리 중...
# [39/423] DEFIUSDT 처리 중...
# [40/423] YFIUSDT 처리 중...
# [41/423] BALUSDT 처리 중...
# [42/423] CRVUSDT 처리 중...
# [43/423] TRBUSDT 처리 중...
# [44/423] RUNEUSDT 처리 중...
# [45/423] SUSHIUSDT 처리 중...
# [46/423] EGLDUSDT 처리 중...
# [47/423] SOLUSDT 처리 중...
# [48/423] ICXUSDT 처리 중...
# [49/423] STORJUSDT 처리 중...
# [50/423] UNIUSDT 처리 중...
# [51/423] AVAXUSDT 처리 중...
# [52/423] ENJUSDT 처리 중...
# [53/423] FLMUSDT 처리 중...
# [54/423] KSMUSDT 처리 중...
# [55/423] NEARUSDT 처리 중...
# [56/423] AAVEUSDT 처리 중...
# [57/423] FILUSDT 처리 중...
# [58/423] RSRUSDT 처리 중...
# [59/423] LRCUSDT 처리 중...
# [60/423] BELUSDT 처리 중...
# [61/423] AXSUSDT 처리 중...
# [62/423] ALPHAUSDT 처리 중...
# [63/423] ZENUSDT 처리 중...
# [64/423] SKLUSDT 처리 중...
# [65/423] GRTUSDT 처리 중...
# [66/423] 1INCHUSDT 처리 중...
# [67/423] CHZUSDT 처리 중...
# [68/423] SANDUSDT 처리 중...
# [69/423] ANKRUSDT 처리 중...
# [70/423] RVNUSDT 처리 중...
# [71/423] SFPUSDT 처리 중...
# [72/423] COTIUSDT 처리 중...
# [73/423] CHRUSDT 처리 중...
# [74/423] MANAUSDT 처리 중...
# [75/423] ALICEUSDT 처리 중...
# [76/423] HBARUSDT 처리 중...
# [77/423] ONEUSDT 처리 중...
# [78/423] DENTUSDT 처리 중...
# [79/423] CELRUSDT 처리 중...
# [80/423] HOTUSDT 처리 중...
# [81/423] MTLUSDT 처리 중...
# [82/423] OGNUSDT 처리 중...
# [83/423] NKNUSDT 처리 중...
# [84/423] 1000SHIBUSDT 처리 중...
# [85/423] BAKEUSDT 처리 중...
# [86/423] GTCUSDT 처리 중...
# [87/423] BTCDOMUSDT 처리 중...
# [88/423] IOTXUSDT 처리 중...
# [89/423] C98USDT 처리 중...
# [90/423] MASKUSDT 처리 중...
# [91/423] ATAUSDT 처리 중...
# [92/423] DYDXUSDT 처리 중...
# [93/423] 1000XECUSDT 처리 중...
# [94/423] GALAUSDT 처리 중...
# [95/423] CELOUSDT 처리 중...
# [96/423] ARUSDT 처리 중...
# [97/423] ARPAUSDT 처리 중...
# [98/423] CTSIUSDT 처리 중...
# [99/423] LPTUSDT 처리 중...
# [100/423] ENSUSDT 처리 중...
# [101/423] PEOPLEUSDT 처리 중...
# [102/423] ROSEUSDT 처리 중...
# [103/423] DUSKUSDT 처리 중...
# [104/423] FLOWUSDT 처리 중...
# [105/423] IMXUSDT 처리 중...
# [106/423] API3USDT 처리 중...
# [107/423] GMTUSDT 처리 중...
# [108/423] APEUSDT 처리 중...
# [109/423] WOOUSDT 처리 중...
# [110/423] JASMYUSDT 처리 중...
# [111/423] OPUSDT 처리 중...
# [112/423] INJUSDT 처리 중...
# [113/423] STGUSDT 처리 중...
# [114/423] SPELLUSDT 처리 중...
# [115/423] 1000LUNCUSDT 처리 중...
# [116/423] LUNA2USDT 처리 중...
# [117/423] LDOUSDT 처리 중...
# [118/423] ICPUSDT 처리 중...
# [119/423] APTUSDT 처리 중...
# [120/423] QNTUSDT 처리 중...
# [121/423] FETUSDT 처리 중...
# [122/423] FXSUSDT 처리 중...
# [123/423] HOOKUSDT 처리 중...
# [124/423] MAGICUSDT 처리 중...
# [125/423] TUSDT 처리 중...
# [126/423] HIGHUSDT 처리 중...
# [127/423] MINAUSDT 처리 중...
# [128/423] ASTRUSDT 처리 중...
# [129/423] PHBUSDT 처리 중...
# [130/423] GMXUSDT 처리 중...
# [131/423] CFXUSDT 처리 중...
# [132/423] STXUSDT 처리 중...
# [133/423] ACHUSDT 처리 중...
# [134/423] SSVUSDT 처리 중...
# [135/423] CKBUSDT 처리 중...
# [136/423] PERPUSDT 처리 중...
# [137/423] TRUUSDT 처리 중...
# [138/423] LQTYUSDT 처리 중...
# [139/423] USDCUSDT 처리 중...
# [140/423] IDUSDT 처리 중...
# [141/423] ARBUSDT 처리 중...
# [142/423] JOEUSDT 처리 중...
# [143/423] TLMUSDT 처리 중...
# [144/423] LEVERUSDT 처리 중...
# [145/423] RDNTUSDT 처리 중...
# [146/423] HFTUSDT 처리 중...
# [147/423] XVSUSDT 처리 중...
# [148/423] ETHBTC 처리 중...
# [149/423] BLURUSDT 처리 중...
# [150/423] EDUUSDT 처리 중...
# [151/423] SUIUSDT 처리 중...
# [152/423] 1000PEPEUSDT 처리 중...
# [153/423] 1000FLOKIUSDT 처리 중...
# [154/423] UMAUSDT 처리 중...
# [155/423] NMRUSDT 처리 중...
# [156/423] MAVUSDT 처리 중...
# [157/423] XVGUSDT 처리 중...
# [158/423] WLDUSDT 처리 중...
# [159/423] PENDLEUSDT 처리 중...
# [160/423] ARKMUSDT 처리 중...
# [161/423] AGLDUSDT 처리 중...
# [162/423] YGGUSDT 처리 중...
# [163/423] DODOXUSDT 처리 중...
# [164/423] BNTUSDT 처리 중...
# [165/423] OXTUSDT 처리 중...
# [166/423] SEIUSDT 처리 중...
# [167/423] CYBERUSDT 처리 중...
# [168/423] HIFIUSDT 처리 중...
# [169/423] ARKUSDT 처리 중...
# [170/423] BICOUSDT 처리 중...
# [171/423] BIGTIMEUSDT 처리 중...
# [172/423] WAXPUSDT 처리 중...
# [173/423] BSVUSDT 처리 중...
# [174/423] RIFUSDT 처리 중...
# [175/423] POLYXUSDT 처리 중...
# [176/423] GASUSDT 처리 중...
# [177/423] POWRUSDT 처리 중...
# [178/423] TIAUSDT 처리 중...
# [179/423] CAKEUSDT 처리 중...
# [180/423] MEMEUSDT 처리 중...
# [181/423] TWTUSDT 처리 중...
# [182/423] TOKENUSDT 처리 중...
# [183/423] ORDIUSDT 처리 중...
# [184/423] STEEMUSDT 처리 중...
# [185/423] BADGERUSDT 처리 중...
# [186/423] ILVUSDT 처리 중...
# [187/423] NTRNUSDT 처리 중...
# [188/423] KASUSDT 처리 중...
# [189/423] BEAMXUSDT 처리 중...
# [190/423] 1000BONKUSDT 처리 중...
# [191/423] PYTHUSDT 처리 중...
# [192/423] SUPERUSDT 처리 중...
# [193/423] USTCUSDT 처리 중...
# [194/423] ONGUSDT 처리 중...
# [195/423] ETHWUSDT 처리 중...
# [196/423] JTOUSDT 처리 중...
# [197/423] 1000SATSUSDT 처리 중...
# [198/423] AUCTIONUSDT 처리 중...
# [199/423] 1000RATSUSDT 처리 중...
# [200/423] ACEUSDT 처리 중...
# [201/423] MOVRUSDT 처리 중...
# [202/423] NFPUSDT 처리 중...
# [203/423] BTCUSDC 처리 중...
# [204/423] ETHUSDC 처리 중...
# [205/423] BNBUSDC 처리 중...
# [206/423] SOLUSDC 처리 중...
# [207/423] XRPUSDC 처리 중...
# [208/423] AIUSDT 처리 중...
# [209/423] XAIUSDT 처리 중...
# [210/423] DOGEUSDC 처리 중...
# [211/423] WIFUSDT 처리 중...
# [212/423] MANTAUSDT 처리 중...
# [213/423] ONDOUSDT 처리 중...
# [214/423] LSKUSDT 처리 중...
# [215/423] ALTUSDT 처리 중...
# [216/423] JUPUSDT 처리 중...
# [217/423] ZETAUSDT 처리 중...
# [218/423] RONINUSDT 처리 중...
# [219/423] DYMUSDT 처리 중...
# [220/423] SUIUSDC 처리 중...
# [221/423] OMUSDT 처리 중...
# [222/423] LINKUSDC 처리 중...
# [223/423] PIXELUSDT 처리 중...
# [224/423] STRKUSDT 처리 중...
# [225/423] ORDIUSDC 처리 중...
# [226/423] GLMUSDT 처리 중...
# [227/423] PORTALUSDT 처리 중...
# [228/423] TONUSDT 처리 중...
# [229/423] AXLUSDT 처리 중...
# [230/423] MYROUSDT 처리 중...
# [231/423] 1000PEPEUSDC 처리 중...
# [232/423] METISUSDT 처리 중...
# [233/423] AEVOUSDT 처리 중...
# [234/423] WLDUSDC 처리 중...
# [235/423] VANRYUSDT 처리 중...
# [236/423] BOMEUSDT 처리 중...
# [237/423] ETHFIUSDT 처리 중...
# [238/423] AVAXUSDC 처리 중...
# [239/423] 1000SHIBUSDC 처리 중...
# [240/423] ENAUSDT 처리 중...
# [241/423] WUSDT 처리 중...
# [242/423] WIFUSDC 처리 중...
# [243/423] BCHUSDC 처리 중...
# [244/423] TNSRUSDT 처리 중...
# [245/423] SAGAUSDT 처리 중...
# [246/423] LTCUSDC 처리 중...
# [247/423] NEARUSDC 처리 중...
# [248/423] TAOUSDT 처리 중...
# [249/423] OMNIUSDT 처리 중...
# [250/423] ARBUSDC 처리 중...
# [251/423] NEOUSDC 처리 중...
# [252/423] FILUSDC 처리 중...
# [253/423] TIAUSDC 처리 중...
# [254/423] BOMEUSDC 처리 중...
# [255/423] REZUSDT 처리 중...
# [256/423] ENAUSDC 처리 중...
# [257/423] ETHFIUSDC 처리 중...
# [258/423] 1000BONKUSDC 처리 중...
# [259/423] BBUSDT 처리 중...
# [260/423] NOTUSDT 처리 중...
# [261/423] TURBOUSDT 처리 중...
# [262/423] IOUSDT 처리 중...
# [263/423] ZKUSDT 처리 중...
# [264/423] MEWUSDT 처리 중...
# [265/423] LISTAUSDT 처리 중...
# [266/423] ZROUSDT 처리 중...
# [267/423] CRVUSDC 처리 중...
# [268/423] RENDERUSDT 처리 중...
# [269/423] BANANAUSDT 처리 중...
# [270/423] RAREUSDT 처리 중...
# [271/423] GUSDT 처리 중...
# [272/423] SYNUSDT 처리 중...
# [273/423] SYSUSDT 처리 중...
# [274/423] VOXELUSDT 처리 중...
# [275/423] BRETTUSDT 처리 중...
# [276/423] ALPACAUSDT 처리 중...
# [277/423] POPCATUSDT 처리 중...
# [278/423] SUNUSDT 처리 중...
# [279/423] VIDTUSDT 처리 중...
# [280/423] NULSUSDT 처리 중...
# [281/423] DOGSUSDT 처리 중...
# [282/423] MBOXUSDT 처리 중...
# [283/423] CHESSUSDT 처리 중...
# [284/423] FLUXUSDT 처리 중...
# [285/423] BSWUSDT 처리 중...
# [286/423] QUICKUSDT 처리 중...
# [287/423] NEIROETHUSDT 처리 중...
# [288/423] RPLUSDT 처리 중...
# [289/423] POLUSDT 처리 중...
# [290/423] UXLINKUSDT 처리 중...
# [291/423] 1MBABYDOGEUSDT 처리 중...
# [292/423] NEIROUSDT 처리 중...
# [293/423] KDAUSDT 처리 중...
# [294/423] FIDAUSDT 처리 중...
# [295/423] FIOUSDT 처리 중...
# [296/423] CATIUSDT 처리 중...
# [297/423] GHSTUSDT 처리 중...
# [298/423] LOKAUSDT 처리 중...
# [299/423] HMSTRUSDT 처리 중...
# [300/423] REIUSDT 처리 중...
# [301/423] COSUSDT 처리 중...
# [302/423] EIGENUSDT 처리 중...
# [303/423] DIAUSDT 처리 중...
# [304/423] 1000CATUSDT 처리 중...
# [305/423] SCRUSDT 처리 중...
# [306/423] GOATUSDT 처리 중...
# [307/423] MOODENGUSDT 처리 중...
# [308/423] SAFEUSDT 처리 중...
# [309/423] SANTOSUSDT 처리 중...
# [310/423] TROYUSDT 처리 중...
# [311/423] PONKEUSDT 처리 중...
# [312/423] COWUSDT 처리 중...
# [313/423] CETUSUSDT 처리 중...
# [314/423] 1000000MOGUSDT 처리 중...
# [315/423] GRASSUSDT 처리 중...
# [316/423] DRIFTUSDT 처리 중...
# [317/423] SWELLUSDT 처리 중...
# [318/423] ACTUSDT 처리 중...
# [319/423] PNUTUSDT 처리 중...
# [320/423] HIPPOUSDT 처리 중...
# [321/423] 1000XUSDT 처리 중...
# [322/423] DEGENUSDT 처리 중...
# [323/423] BANUSDT 처리 중...
# [324/423] AKTUSDT 처리 중...
# [325/423] SLERFUSDT 처리 중...
# [326/423] SCRTUSDT 처리 중...
# [327/423] 1000CHEEMSUSDT 처리 중...
# [328/423] 1000WHYUSDT 처리 중...
# [329/423] THEUSDT 처리 중...
# [330/423] MORPHOUSDT 처리 중...
# [331/423] CHILLGUYUSDT 처리 중...
# [332/423] KAIAUSDT 처리 중...
# [333/423] AEROUSDT 처리 중...
# [334/423] ACXUSDT 처리 중...
# [335/423] ORCAUSDT 처리 중...
# [336/423] MOVEUSDT 처리 중...
# [337/423] RAYSOLUSDT 처리 중...
# [338/423] KOMAUSDT 처리 중...
# [339/423] VIRTUALUSDT 처리 중...
# [340/423] SPXUSDT 처리 중...
# [341/423] MEUSDT 처리 중...
# [342/423] AVAUSDT 처리 중...
# [343/423] DEGOUSDT 처리 중...
# [344/423] VELODROMEUSDT 처리 중...
# [345/423] MOCAUSDT 처리 중...
# [346/423] VANAUSDT 처리 중...
# [347/423] PENGUUSDT 처리 중...
# [348/423] LUMIAUSDT 처리 중...
# [349/423] USUALUSDT 처리 중...
# [350/423] AIXBTUSDT 처리 중...
# [351/423] FARTCOINUSDT 처리 중...
# [352/423] KMNOUSDT 처리 중...
# [353/423] CGPTUSDT 처리 중...
# [354/423] HIVEUSDT 처리 중...
# [355/423] DEXEUSDT 처리 중...
# [356/423] BTCUSDT_250627 처리 중...
# [357/423] ETHUSDT_250627 처리 중...
# [358/423] PHAUSDT 처리 중...
# [359/423] DFUSDT 처리 중...
# [360/423] GRIFFAINUSDT 처리 중...
# [361/423] AI16ZUSDT 처리 중...
# [362/423] ZEREBROUSDT 처리 중...
# [363/423] BIOUSDT 처리 중...
# [364/423] COOKIEUSDT 처리 중...
# [365/423] ALCHUSDT 처리 중...
# [366/423] SWARMSUSDT 처리 중...
# [367/423] SONICUSDT 처리 중...
# [368/423] DUSDT 처리 중...
# [369/423] PROMUSDT 처리 중...
# [370/423] SUSDT 처리 중...
# [371/423] SOLVUSDT 처리 중...
# [372/423] ARCUSDT 처리 중...
# [373/423] AVAAIUSDT 처리 중...
# [374/423] TRUMPUSDT 처리 중...
# [375/423] MELANIAUSDT 처리 중...
# [376/423] VTHOUSDT 처리 중...
# [377/423] ANIMEUSDT 처리 중...
# [378/423] VINEUSDT 처리 중...
# [379/423] PIPPINUSDT 처리 중...
# [380/423] VVVUSDT 처리 중...
# [381/423] BERAUSDT 처리 중...
# [382/423] TSTUSDT 처리 중...
# [383/423] LAYERUSDT 처리 중...
# [384/423] HEIUSDT 처리 중...
# [385/423] B3USDT 처리 중...
# [386/423] IPUSDT 처리 중...
# [387/423] GPSUSDT 처리 중...
# [388/423] SHELLUSDT 처리 중...
# [389/423] KAITOUSDT 처리 중...
# [390/423] KAITOUSDC 처리 중...
# [391/423] IPUSDC 처리 중...
# [392/423] TRUMPUSDC 처리 중...
# [393/423] ADAUSDC 처리 중...
# [394/423] REDUSDT 처리 중...
# [395/423] PNUTUSDC 처리 중...
# [396/423] HBARUSDC 처리 중...
# [397/423] VICUSDT 처리 중...
# [398/423] EPICUSDT 처리 중...
# [399/423] BMTUSDT 처리 중...
# [400/423] MUBARAKUSDT 처리 중...
# [401/423] FORMUSDT 처리 중...
# [402/423] BIDUSDT 처리 중...
# [403/423] TUTUSDT 처리 중...
# [404/423] BROCCOLI714USDT 처리 중...
# [405/423] BROCCOLIF3BUSDT 처리 중...
# [406/423] SIRENUSDT 처리 중...
# [407/423] BANANAS31USDT 처리 중...
# [408/423] BRUSDT 처리 중...
# [409/423] PLUMEUSDT 처리 중...
# [410/423] NILUSDT 처리 중...
# [411/423] PARTIUSDT 처리 중...
# [412/423] JELLYJELLYUSDT 처리 중...
# [413/423] MAVIAUSDT 처리 중...
# [414/423] PAXGUSDT 처리 중...
# [415/423] WALUSDT 처리 중...
# [416/423] BTCUSDT_250926 처리 중...
# [417/423] ETHUSDT_250926 처리 중...
# [418/423] FUNUSDT 처리 중...
# [419/423] MLNUSDT 처리 중...
# [420/423] GUNUSDT 처리 중...
# [421/423] ATHUSDT 처리 중...
# [422/423] BABYUSDT 처리 중...
# [423/423] FORTHUSDT 처리 중...
#            symbol     avg_price    avg_volume    market_cap
# 0         BTCUSDT  68461.051613  3.399354e+05  2.327234e+10
# 1         ETHUSDT   3575.691290  2.888505e+06  1.032840e+10
# 2         SOLUSDT    178.525097  2.627377e+07  4.690527e+09
# 3        DOGEUSDT      0.175816  1.166988e+10  2.051753e+09
# 4         ENAUSDT      1.028667  1.377274e+09  1.416756e+09
# ..            ...           ...           ...           ...
# 238    BTCDOMUSDT   2251.490323  2.243988e+03  5.052318e+06
# 239      AVAXUSDC     52.131526  8.285269e+04  4.319237e+06
# 240      DEFIUSDT   1287.625806  2.613028e+03  3.364602e+06
# 241  1000SHIBUSDC      0.028654  8.461280e+07  2.424465e+06
# 242        ETHBTC      0.052234  2.988348e+04  1.560940e+03
#
# [243 rows x 4 columns]

# %% [markdown]
# #1 최근 순위 2025-03-08 ~ 2025-04-07
#
#
# ['BTCUSDT',
#  'ETHUSDT',
#  'SOLUSDT',
#  'XRPUSDT',
#  'BTCUSDC',
#  'DOGEUSDT',
#  'ETHUSDC',
#  '1000PEPEUSDT',
#  'SUIUSDT',
#  'BNBUSDT']
#
#  데이터 수집 기간: 2024-03-08 00:00:00 ~ 2024-04-07 00:00:00
#  ['BTCUSDT',
#  'ETHUSDT',
#  'SOLUSDT',
#  'DOGEUSDT',
#  'ENAUSDT', *
#  '1000PEPEUSDT',
#  'WIFUSDT', *
#  'BOMEUSDT', *]

# %%
print(Future_db.get_top10_futures.__doc__)
# Out:
# 시가총액 기준 상위 10개 선물 종목을 반환합니다.
#
#         (self, symbols_option=1, symobls_list == None)
#
#         Param
#
#         interval = '30m'  : 시간간격 (1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w, 1M)
#         symbols_option==1 : api에서 받은 심볼을 슬라이싱 합니다.
#         symbols_option==2 : 현재로부터 한달전의 마켓 켑을 두고, 약 422개를 계산한 후 10를 선별합니다.
#         symbols_option==3 : 임의로 지정한 symbols_list 를 심볼로 사용합니다.(날짜를 변경할 때 사용)
#             symobls_list: 심볼리스트를 지정해서 데이터를 가져옵니다.(option 3와 함꼐사용)

# %%
list(symbols_marketcap['symbol'][:10])
# Out:
# ['BTCUSDT',
#  'ETHUSDT',
#  'SOLUSDT',
#  'DOGEUSDT',
#  'ENAUSDT',
#  '1000PEPEUSDT',
#  'WIFUSDT',
#  'BOMEUSDT',
#  'XRPUSDT',
#  'BNBUSDT']

# %%
#2025년도 기준 심볼 적용
futures_10 = futures.get_top10_futures(symbols_option=3, symobls_list = list(symbols_marketcap['symbol'][:10]))
futures_10
# Out:
# [1/10] BTCUSDT 처리 중...
# [2/10] ETHUSDT 처리 중...
# [3/10] SOLUSDT 처리 중...
# [4/10] DOGEUSDT 처리 중...
# [5/10] ENAUSDT 처리 중...
# [6/10] 1000PEPEUSDT 처리 중...
# [7/10] WIFUSDT 처리 중...
# [8/10] BOMEUSDT 처리 중...
# [9/10] XRPUSDT 처리 중...
# [10/10] BNBUSDT 처리 중...
#                       BTCUSDT  ETHUSDT  SOLUSDT  DOGEUSDT  ENAUSDT  \
# timestamp
# 2019-09-08 17:30:00  10000.00      NaN      NaN       NaN      NaN
# 2019-09-08 18:00:00  10000.00      NaN      NaN       NaN      NaN
# 2019-09-08 18:30:00  10000.00      NaN      NaN       NaN      NaN
# 2019-09-08 19:00:00  10354.62      NaN      NaN       NaN      NaN
# 2019-09-08 19:30:00  10340.12      NaN      NaN       NaN      NaN
# ...                       ...      ...      ...       ...      ...
# 2025-04-07 22:00:00  79776.50  1580.12   109.00   0.15225   0.2945
# 2025-04-07 22:30:00  79919.50  1577.83   108.50   0.15103   0.2946
# 2025-04-07 23:00:00  79819.60  1565.44   107.76   0.14970   0.2927
# 2025-04-07 23:30:00  79140.00  1552.44   106.91   0.14951   0.2922
# 2025-04-08 00:00:00  79311.10  1553.57   107.16   0.14913   0.2897
#
#                      1000PEPEUSDT  WIFUSDT  BOMEUSDT  XRPUSDT  BNBUSDT
# timestamp
# 2019-09-08 17:30:00           NaN      NaN       NaN      NaN      NaN
# 2019-09-08 18:00:00           NaN      NaN       NaN      NaN      NaN
# 2019-09-08 18:30:00           NaN      NaN       NaN      NaN      NaN
# 2019-09-08 19:00:00           NaN      NaN       NaN      NaN      NaN
# 2019-09-08 19:30:00           NaN      NaN       NaN      NaN      NaN
# ...                           ...      ...       ...      ...      ...
# 2025-04-07 22:00:00      0.006574   0.3492  0.001045   1.9392   559.32
# 2025-04-07 22:30:00      0.006543   0.3471  0.001039   1.9288   558.47
# 2025-04-07 23:00:00      0.006471   0.3456  0.001033   1.9089   556.59
# 2025-04-07 23:30:00      0.006450   0.3433  0.001031   1.8974   554.63
# 2025-04-08 00:00:00      0.006423   0.3420  0.001030   1.8873   555.66
#
# [97838 rows x 10 columns]

# %%
futures_10.to_parquet("futures_10_19_25.parquet", engine='pyarrow')
futures_10.to_excel('futures_10_19_25.xlsx',index = True )
