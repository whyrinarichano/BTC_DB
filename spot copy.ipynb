# %%
# 필요한 라이브러리 임포트
from binance.client import Client
from binance.enums import *
import pandas as pd
from datetime import datetime , timedelta
import time

import pandas as pd
import numpy as np
import torch
import pyarrow

# %%
# API 키 설정
api_key = ''
api_secret = ''


# 바이낸스 클라이언트 초기화
client = Client(api_key, api_secret)

# %%
class Spot:
    def __init__(self):
        self.spot = None
        self.curent_symbols = self.get_all_spot_symbols()
    
    def get_all_spot_symbols(self):
        """
            거래 가능한 모든 현물 심볼 목록 반환
        """
        try:
            exchange_info = client.get_exchange_info()
            return [symbol['symbol'] for symbol in exchange_info['symbols'] if symbol['status'] == 'TRADING' and symbol['quoteAsset'] == 'USDT']
        except Exception as e:
            print(f"심볼 목록 조회 에러: {e}")
            return None
    
    def get_spot_klines(self,symbol='BTCUSDT', interval='1d', limit=500):
        """
        현물 캔들스틱 데이터 가져오기
        :param symbol: 거래쌍 (예: 'BTCUSDT')
        :param interval: 시간간격 (1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w, 1M)
        :param limit: 가져올 캔들 수
        :return: DataFrame
        """
        try:
            klines = client.get_historical_klines(symbol=symbol, interval=interval, limit=limit)
            
            # DataFrame 생성
            df = pd.DataFrame(klines, columns=['timestamp', 'open', 'high', 'low', 'close', 
                                            'volume', 'close_time', 'quote_asset_volume', 'number_of_trades',
                                            'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])
            
            # 데이터 타입 변환
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
            for col in ['open', 'high', 'low', 'close', 'volume', 'quote_asset_volume']:
                df[col] = df[col].astype(float)
                
            return df[['timestamp', 'close']]
        
        except Exception as e:
            print(f"에러 발생: {e}")
            return None
    
    def get_spot_historical_klines(self, symbol='BTCUSDT', interval='1d', start_str='2017-01-01', end_str=None):
        """
        특정 기간의 현물 캔들스틱 데이터 가져오기
        :param symbol: 거래쌍 또는 'all'
        :param interval: 시간간격
        :param start_str: 시작 날짜 (YYYY-MM-DD)
        :param end_str: 종료 날짜 (YYYY-MM-DD)
        :return: Dictionary of DataFrames (symbol을 'all'로 지정한 경우) 또는 단일 DataFrame
        """
        try:
            # 날짜를 타임스탬프로 변환
            start_ts = int(pd.Timestamp(start_str).timestamp() * 1000)

            if end_str == None:
                end_ts = datetime.now().strftime('%Y-%m-%d')
                end_ts = int(pd.Timestamp(end_ts).timestamp() * 1000)
            else:
                end_ts = int(pd.Timestamp(end_str).timestamp() * 1000)

            if symbol.lower() == 'all':
                symbols = self.get_all_spot_symbols()
                if not symbols:
                    return None
                
                result = {}
                for sym in symbols:
                    print(f"{sym} 데이터 수집 중...")
                    klines = []
                    while start_ts < end_ts:
                        temp_data = client.get_historical_klines(
                            symbol=sym,
                            interval=interval,
                            start_str=str(start_ts),
                            end_str=str(end_ts),
                            limit=1000
                        )
                        if not temp_data:
                            break
                        klines.extend(temp_data)
                        start_ts = temp_data[-1][0] + 1  # 다음 시작점을 마지막 데이터의 다음 시점으로 설정
                        time.sleep(0.1)  # API 호출 제한 방지
                    
                    if klines:
                        df = pd.DataFrame(klines, columns=['timestamp', 'open', 'high', 'low', 'close', 
                                                        'volume', 'close_time', 'quote_volume', 'trades',
                                                        'taker_base', 'taker_quote', 'ignore'])
                        df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
                        for col in ['open', 'high', 'low', 'close', 'volume', 'quote_volume']:
                            df[col] = df[col].astype(float)
                        result[sym] = df[['timestamp', 'open', 'high', 'low', 'close', 'volume', 'quote_volume']]
                    time.sleep(0.5)
                return result
            
            else:
                klines = []
                while start_ts < end_ts:
                    temp_data = client.get_historical_klines(
                        symbol=symbol,
                        interval=interval,
                        start_str=str(start_ts),
                        end_str=str(end_ts),
                        limit=1000
                    )
                    if not temp_data:
                        break
                    klines.extend(temp_data)
                    start_ts = temp_data[-1][0] + 1  # 다음 시작점을 마지막 데이터의 다음 시점으로 설정
                    time.sleep(0.1)  # API 호출 제한 방지
                
                df = pd.DataFrame(klines, columns=['timestamp', 'open', 'high', 'low', 'close', 
                                                'volume', 'close_time', 'quote_volume', 'trades',
                                                'taker_base', 'taker_quote', 'ignore'])
                
                df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
                for col in ['open', 'high', 'low', 'close', 'volume', 'quote_volume']:
                    df[col] = df[col].astype(float)
                    
                return df[['timestamp', 'open', 'high', 'low', 'close', 'volume']]
        
        except Exception as e:
            print(f"에러 발생: {e}")
            return None
    
    def fetch_and_merge_close_prices(self, interval='1d', limit=2000):
        """
        모든 심볼의 종가 데이터를 불러와 병합한 DataFrame 반환
        :param interval: 시간간격
        :param limit: 가져올 캔들 수
        :return: 병합된 DataFrame
        """
        symbols = self.get_all_spot_symbols()
        if not symbols:
            return None
        
        merged_df = pd.DataFrame()

        for i, symbol in enumerate(symbols):
            print(f"[{i+1}/{len(symbols)}] {symbol} 처리 중...")
            df = self.get_spot_historical_klines(symbol, '1d','2017-01-01')
            if df is not None:
                df = df[['timestamp', 'close']].copy()
                df = df.rename(columns={'close': symbol})
                if merged_df.empty:
                    merged_df = df
                else:
                    merged_df = pd.merge(merged_df, df, on='timestamp', how='outer')
            else:
                # 데이터가 없을 경우 NaN으로 처리
                if merged_df.empty:
                    merged_df = pd.DataFrame({'timestamp': pd.date_range(start='2017-01-01', end=pd.Timestamp.now(), freq='D')})
                merged_df[symbol] = np.nan  # NaN으로 추가
            time.sleep(2 + np.random.rand())  # API 호출 제한 방지

        merged_df = merged_df.sort_values('timestamp').reset_index(drop=True)
        merged_df.set_index('timestamp', inplace=True)
        self.spot = merged_df.copy()
        return merged_df

# %%
#심볼 확인
spots = Spot()
spots_symbols = spots.get_all_spot_symbols()
print(spots_symbols)
# Out:
# ['BTCUSDT', 'ETHUSDT', 'BNBUSDT', 'NEOUSDT', 'LTCUSDT', 'QTUMUSDT', 'ADAUSDT', 'XRPUSDT', 'EOSUSDT', 'TUSDUSDT', 'IOTAUSDT', 'XLMUSDT', 'ONTUSDT', 'TRXUSDT', 'ETCUSDT', 'ICXUSDT', 'NULSUSDT', 'VETUSDT', 'USDCUSDT', 'LINKUSDT', 'ONGUSDT', 'HOTUSDT', 'ZILUSDT', 'ZRXUSDT', 'FETUSDT', 'BATUSDT', 'ZECUSDT', 'IOSTUSDT', 'CELRUSDT', 'DASHUSDT', 'THETAUSDT', 'ENJUSDT', 'ATOMUSDT', 'TFUELUSDT', 'ONEUSDT', 'ALGOUSDT', 'DOGEUSDT', 'DUSKUSDT', 'ANKRUSDT', 'WINUSDT', 'COSUSDT', 'MTLUSDT', 'DENTUSDT', 'WANUSDT', 'FUNUSDT', 'CVCUSDT', 'CHZUSDT', 'BANDUSDT', 'XTZUSDT', 'RVNUSDT', 'HBARUSDT', 'NKNUSDT', 'STXUSDT', 'KAVAUSDT', 'ARPAUSDT', 'IOTXUSDT', 'RLCUSDT', 'CTXCUSDT', 'BCHUSDT', 'TROYUSDT', 'FTTUSDT', 'EURUSDT', 'OGNUSDT', 'LSKUSDT', 'BNTUSDT', 'LTOUSDT', 'MBLUSDT', 'COTIUSDT', 'STPTUSDT', 'DATAUSDT', 'SOLUSDT', 'CTSIUSDT', 'HIVEUSDT', 'CHRUSDT', 'ARDRUSDT', 'MDTUSDT', 'KNCUSDT', 'LRCUSDT', 'COMPUSDT', 'SCUSDT', 'ZENUSDT', 'SNXUSDT', 'VTHOUSDT', 'DGBUSDT', 'SXPUSDT', 'MKRUSDT', 'DCRUSDT', 'STORJUSDT', 'MANAUSDT', 'YFIUSDT', 'BALUSDT', 'KMDUSDT', 'JSTUSDT', 'CRVUSDT', 'SANDUSDT', 'NMRUSDT', 'DOTUSDT', 'LUNAUSDT', 'RSRUSDT', 'PAXGUSDT', 'TRBUSDT', 'SUSHIUSDT', 'KSMUSDT', 'EGLDUSDT', 'DIAUSDT', 'RUNEUSDT', 'FIOUSDT', 'UMAUSDT', 'BELUSDT', 'WINGUSDT', 'UNIUSDT', 'OXTUSDT', 'SUNUSDT', 'AVAXUSDT', 'FLMUSDT', 'UTKUSDT', 'XVSUSDT', 'ALPHAUSDT', 'AAVEUSDT', 'NEARUSDT', 'FILUSDT', 'INJUSDT', 'AUDIOUSDT', 'CTKUSDT', 'AXSUSDT', 'HARDUSDT', 'STRAXUSDT', 'ROSEUSDT', 'AVAUSDT', 'SKLUSDT', 'GRTUSDT', 'JUVUSDT', 'PSGUSDT', '1INCHUSDT', 'OGUSDT', 'ATMUSDT', 'ASRUSDT', 'CELOUSDT', 'RIFUSDT', 'TRUUSDT', 'CKBUSDT', 'TWTUSDT', 'FIROUSDT', 'SFPUSDT', 'DODOUSDT', 'CAKEUSDT', 'ACMUSDT', 'BADGERUSDT', 'FISUSDT', 'OMUSDT', 'PONDUSDT', 'DEGOUSDT', 'ALICEUSDT', 'PERPUSDT', 'SUPERUSDT', 'CFXUSDT', 'TKOUSDT', 'PUNDIXUSDT', 'TLMUSDT', 'BARUSDT', 'FORTHUSDT', 'BAKEUSDT', 'SLPUSDT', 'SHIBUSDT', 'ICPUSDT', 'ARUSDT', 'MASKUSDT', 'LPTUSDT', 'XVGUSDT', 'ATAUSDT', 'GTCUSDT', 'PHAUSDT', 'MLNUSDT', 'DEXEUSDT', 'C98USDT', 'QNTUSDT', 'FLOWUSDT', 'MINAUSDT', 'RAYUSDT', 'FARMUSDT', 'ALPACAUSDT', 'QUICKUSDT', 'MBOXUSDT', 'REQUSDT', 'GHSTUSDT', 'WAXPUSDT', 'GNOUSDT', 'XECUSDT', 'ELFUSDT', 'DYDXUSDT', 'IDEXUSDT', 'VIDTUSDT', 'USDPUSDT', 'GALAUSDT', 'ILVUSDT', 'YGGUSDT', 'SYSUSDT', 'DFUSDT', 'FIDAUSDT', 'AGLDUSDT', 'RADUSDT', 'BETAUSDT', 'RAREUSDT', 'LAZIOUSDT', 'CHESSUSDT', 'ADXUSDT', 'AUCTIONUSDT', 'MOVRUSDT', 'CITYUSDT', 'ENSUSDT', 'QIUSDT', 'PORTOUSDT', 'POWRUSDT', 'JASMYUSDT', 'AMPUSDT', 'PYRUSDT', 'ALCXUSDT', 'SANTOSUSDT', 'BICOUSDT', 'FLUXUSDT', 'FXSUSDT', 'VOXELUSDT', 'HIGHUSDT', 'CVXUSDT', 'PEOPLEUSDT', 'SPELLUSDT', 'JOEUSDT', 'ACHUSDT', 'IMXUSDT', 'GLMRUSDT', 'LOKAUSDT', 'SCRTUSDT', 'API3USDT', 'BTTCUSDT', 'ACAUSDT', 'XNOUSDT', 'WOOUSDT', 'ALPINEUSDT', 'TUSDT', 'ASTRUSDT', 'GMTUSDT', 'KDAUSDT', 'APEUSDT', 'BSWUSDT', 'BIFIUSDT', 'STEEMUSDT', 'NEXOUSDT', 'REIUSDT', 'LDOUSDT', 'OPUSDT', 'LEVERUSDT', 'STGUSDT', 'LUNCUSDT', 'GMXUSDT', 'POLYXUSDT', 'APTUSDT', 'OSMOUSDT', 'HFTUSDT', 'PHBUSDT', 'HOOKUSDT', 'MAGICUSDT', 'HIFIUSDT', 'RPLUSDT', 'PROSUSDT', 'GNSUSDT', 'SYNUSDT', 'VIBUSDT', 'SSVUSDT', 'LQTYUSDT', 'USTCUSDT', 'GASUSDT', 'GLMUSDT', 'PROMUSDT', 'QKCUSDT', 'UFTUSDT', 'IDUSDT', 'ARBUSDT', 'RDNTUSDT', 'WBTCUSDT', 'EDUUSDT', 'SUIUSDT', 'PEPEUSDT', 'FLOKIUSDT', 'SNTUSDT', 'MAVUSDT', 'PENDLEUSDT', 'ARKMUSDT', 'WBETHUSDT', 'WLDUSDT', 'FDUSDUSDT', 'SEIUSDT', 'CYBERUSDT', 'ARKUSDT', 'CREAMUSDT', 'IQUSDT', 'NTRNUSDT', 'TIAUSDT', 'MEMEUSDT', 'ORDIUSDT', 'BEAMXUSDT', 'PIVXUSDT', 'VICUSDT', 'BLURUSDT', 'VANRYUSDT', 'AEURUSDT', 'JTOUSDT', '1000SATSUSDT', 'BONKUSDT', 'ACEUSDT', 'NFPUSDT', 'AIUSDT', 'XAIUSDT', 'MANTAUSDT', 'ALTUSDT', 'JUPUSDT', 'PYTHUSDT', 'RONINUSDT', 'DYMUSDT', 'PIXELUSDT', 'STRKUSDT', 'PORTALUSDT', 'PDAUSDT', 'AXLUSDT', 'WIFUSDT', 'METISUSDT', 'AEVOUSDT', 'BOMEUSDT', 'ETHFIUSDT', 'ENAUSDT', 'WUSDT', 'TNSRUSDT', 'SAGAUSDT', 'TAOUSDT', 'OMNIUSDT', 'REZUSDT', 'BBUSDT', 'NOTUSDT', 'IOUSDT', 'ZKUSDT', 'LISTAUSDT', 'ZROUSDT', 'GUSDT', 'BANANAUSDT', 'RENDERUSDT', 'TONUSDT', 'DOGS ...

# %%
#데이터 가져오기
print(Spot.get_spot_historical_klines.__doc__)
# Out:
#         특정 기간의 현물 캔들스틱 데이터 가져오기
#         :param symbol: 거래쌍 또는 'all'
#         :param interval: 시간간격
#         :param start_str: 시작 날짜 (YYYY-MM-DD)
#         :param end_str: 종료 날짜 (YYYY-MM-DD)
#         :return: Dictionary of DataFrames (symbol을 'all'로 지정한 경우) 또는 단일 DataFrame

# %%
#적용 예시1
df = spots.get_spot_historical_klines('BTCUSDT', '1d','2017-01-01')
df
# Out:
#       timestamp      open      high       low     close        volume
# 0    2017-08-17   4261.48   4485.39   4200.74   4285.08    795.150377
# 1    2017-08-18   4285.08   4371.52   3938.77   4108.37   1199.888264
# 2    2017-08-19   4108.37   4184.69   3850.00   4139.98    381.309763
# 3    2017-08-20   4120.98   4211.08   4032.62   4086.29    467.083022
# 4    2017-08-21   4069.13   4119.62   3911.79   4016.00    691.743060
# ...         ...       ...       ...       ...       ...           ...
# 2787 2025-04-04  83213.09  84720.00  81659.00  83889.87  32915.539760
# 2788 2025-04-05  83889.87  84266.00  82379.95  83537.99   9360.404680
# 2789 2025-04-06  83537.99  83817.63  77153.83  78430.00  27942.714360
# 2790 2025-04-07  78430.00  81243.58  74508.00  79163.24  78387.530890
# 2791 2025-04-08  79163.24  80867.99  78772.14  78952.00  10613.955300
#
# [2792 rows x 6 columns]

# %%
#적용 예시 2
df = spots.get_spot_historical_klines('ETHUSDT', '1d','2017-01-01')
df
# Out:
#       timestamp     open     high      low    close        volume
# 0    2017-08-17   301.13   312.18   298.00   302.00  7.030710e+03
# 1    2017-08-18   302.00   311.79   283.94   293.96  9.537846e+03
# 2    2017-08-19   293.31   299.90   278.00   290.91  2.146198e+03
# 3    2017-08-20   289.41   300.53   282.85   299.10  2.510139e+03
# 4    2017-08-21   299.10   346.52   294.60   323.29  5.219445e+03
# ...         ...      ...      ...      ...      ...           ...
# 2787 2025-04-04  1817.23  1835.68  1758.72  1816.87  5.727345e+05
# 2788 2025-04-05  1816.88  1827.29  1764.39  1806.01  2.017163e+05
# 2789 2025-04-06  1806.02  1817.00  1537.50  1580.76  9.798471e+05
# 2790 2025-04-07  1580.77  1639.00  1411.01  1553.04  2.168796e+06
# 2791 2025-04-08  1553.04  1618.67  1541.04  1569.60  2.394882e+05
#
# [2792 rows x 6 columns]

# %%
#전 bitcoin 현물 데이터 수집
spot_df = spots.fetch_and_merge_close_prices()
# Out:
# [1/402] BTCUSDT 처리 중...
# [2/402] ETHUSDT 처리 중...
# [3/402] BNBUSDT 처리 중...
# [4/402] NEOUSDT 처리 중...
# [5/402] LTCUSDT 처리 중...
# [6/402] QTUMUSDT 처리 중...
# [7/402] ADAUSDT 처리 중...
# [8/402] XRPUSDT 처리 중...
# [9/402] EOSUSDT 처리 중...
# [10/402] TUSDUSDT 처리 중...
# [11/402] IOTAUSDT 처리 중...
# [12/402] XLMUSDT 처리 중...
# [13/402] ONTUSDT 처리 중...
# [14/402] TRXUSDT 처리 중...
# [15/402] ETCUSDT 처리 중...
# [16/402] ICXUSDT 처리 중...
# [17/402] NULSUSDT 처리 중...
# [18/402] VETUSDT 처리 중...
# [19/402] USDCUSDT 처리 중...
# [20/402] LINKUSDT 처리 중...
# [21/402] ONGUSDT 처리 중...
# [22/402] HOTUSDT 처리 중...
# [23/402] ZILUSDT 처리 중...
# [24/402] ZRXUSDT 처리 중...
# [25/402] FETUSDT 처리 중...
# [26/402] BATUSDT 처리 중...
# [27/402] ZECUSDT 처리 중...
# [28/402] IOSTUSDT 처리 중...
# [29/402] CELRUSDT 처리 중...
# [30/402] DASHUSDT 처리 중...
# [31/402] THETAUSDT 처리 중...
# [32/402] ENJUSDT 처리 중...
# [33/402] ATOMUSDT 처리 중...
# [34/402] TFUELUSDT 처리 중...
# [35/402] ONEUSDT 처리 중...
# [36/402] ALGOUSDT 처리 중...
# [37/402] DOGEUSDT 처리 중...
# [38/402] DUSKUSDT 처리 중...
# [39/402] ANKRUSDT 처리 중...
# [40/402] WINUSDT 처리 중...
# [41/402] COSUSDT 처리 중...
# [42/402] MTLUSDT 처리 중...
# [43/402] DENTUSDT 처리 중...
# [44/402] WANUSDT 처리 중...
# [45/402] FUNUSDT 처리 중...
# [46/402] CVCUSDT 처리 중...
# [47/402] CHZUSDT 처리 중...
# [48/402] BANDUSDT 처리 중...
# [49/402] XTZUSDT 처리 중...
# [50/402] RVNUSDT 처리 중...
# [51/402] HBARUSDT 처리 중...
# [52/402] NKNUSDT 처리 중...
# [53/402] STXUSDT 처리 중...
# [54/402] KAVAUSDT 처리 중...
# [55/402] ARPAUSDT 처리 중...
# [56/402] IOTXUSDT 처리 중...
# [57/402] RLCUSDT 처리 중...
# [58/402] CTXCUSDT 처리 중...
# [59/402] BCHUSDT 처리 중...
# [60/402] TROYUSDT 처리 중...
# [61/402] FTTUSDT 처리 중...
# [62/402] EURUSDT 처리 중...
# [63/402] OGNUSDT 처리 중...
# [64/402] LSKUSDT 처리 중...
# [65/402] BNTUSDT 처리 중...
# [66/402] LTOUSDT 처리 중...
# [67/402] MBLUSDT 처리 중...
# [68/402] COTIUSDT 처리 중...
# [69/402] STPTUSDT 처리 중...
# [70/402] DATAUSDT 처리 중...
# [71/402] SOLUSDT 처리 중...
# [72/402] CTSIUSDT 처리 중...
# [73/402] HIVEUSDT 처리 중...
# [74/402] CHRUSDT 처리 중...
# [75/402] ARDRUSDT 처리 중...
# [76/402] MDTUSDT 처리 중...
# [77/402] KNCUSDT 처리 중...
# [78/402] LRCUSDT 처리 중...
# [79/402] COMPUSDT 처리 중...
# [80/402] SCUSDT 처리 중...
# [81/402] ZENUSDT 처리 중...
# [82/402] SNXUSDT 처리 중...
# [83/402] VTHOUSDT 처리 중...
# [84/402] DGBUSDT 처리 중...
# [85/402] SXPUSDT 처리 중...
# [86/402] MKRUSDT 처리 중...
# [87/402] DCRUSDT 처리 중...
# [88/402] STORJUSDT 처리 중...
# [89/402] MANAUSDT 처리 중...
# [90/402] YFIUSDT 처리 중...
# [91/402] BALUSDT 처리 중...
# [92/402] KMDUSDT 처리 중...
# [93/402] JSTUSDT 처리 중...
# [94/402] CRVUSDT 처리 중...
# [95/402] SANDUSDT 처리 중...
# [96/402] NMRUSDT 처리 중...
# [97/402] DOTUSDT 처리 중...
# [98/402] LUNAUSDT 처리 중...
# [99/402] RSRUSDT 처리 중...
# [100/402] PAXGUSDT 처리 중...
# [101/402] TRBUSDT 처리 중...
# [102/402] SUSHIUSDT 처리 중...
# [103/402] KSMUSDT 처리 중...
# [104/402] EGLDUSDT 처리 중...
# [105/402] DIAUSDT 처리 중...
# [106/402] RUNEUSDT 처리 중...
# [107/402] FIOUSDT 처리 중...
# [108/402] UMAUSDT 처리 중...
# [109/402] BELUSDT 처리 중...
# [110/402] WINGUSDT 처리 중...
# [111/402] UNIUSDT 처리 중...
# [112/402] OXTUSDT 처리 중...
# [113/402] SUNUSDT 처리 중...
# [114/402] AVAXUSDT 처리 중...
# [115/402] FLMUSDT 처리 중...
# [116/402] UTKUSDT 처리 중...
# [117/402] XVSUSDT 처리 중...
# [118/402] ALPHAUSDT 처리 중...
# [119/402] AAVEUSDT 처리 중...
# [120/402] NEARUSDT 처리 중...
# [121/402] FILUSDT 처리 중...
# [122/402] INJUSDT 처리 중...
# [123/402] AUDIOUSDT 처리 중...
# [124/402] CTKUSDT 처리 중...
# [125/402] AXSUSDT 처리 중...
# [126/402] HARDUSDT 처리 중...
# [127/402] STRAXUSDT 처리 중...
# [128/402] ROSEUSDT 처리 중...
# [129/402] AVAUSDT 처리 중...
# [130/402] SKLUSDT 처리 중...
# [131/402] GRTUSDT 처리 중...
# [132/402] JUVUSDT 처리 중...
# [133/402] PSGUSDT 처리 중...
# [134/402] 1INCHUSDT 처리 중...
# [135/402] OGUSDT 처리 중...
# [136/402] ATMUSDT 처리 중...
# [137/402] ASRUSDT 처리 중...
# [138/402] CELOUSDT 처리 중...
# [139/402] RIFUSDT 처리 중...
# [140/402] TRUUSDT 처리 중...
# [141/402] CKBUSDT 처리 중...
# [142/402] TWTUSDT 처리 중...
# [143/402] FIROUSDT 처리 중...
# [144/402] SFPUSDT 처리 중...
# [145/402] DODOUSDT 처리 중...
# [146/402] CAKEUSDT 처리 중...
# [147/402] ACMUSDT 처리 중...
# [148/402] BADGERUSDT 처리 중...
# [149/402] FISUSDT 처리 중...
# [150/402] OMUSDT 처리 중...
# [151/402] PONDUSDT 처리 중...
# [152/402] DEGOUSDT 처리 중...
# [153/402] ALICEUSDT 처리 중...
# [154/402] PERPUSDT 처리 중...
# [155/402] SUPERUSDT 처리 중...
# [156/402] CFXUSDT 처리 중...
# [157/402] TKOUSDT 처리 중...
# [158/402] PUNDIXUSDT 처리 중...
# [159/402] TLMUSDT 처리 중...
# [160/402] BARUSDT 처리 중...
# [161/402] FORTHUSDT 처리 중...
# [162/402] BAKEUSDT 처리 중...
# [163/402] SLPUSDT 처리 중...
# [164/402] SHIBUSDT 처리 중...
# [165/402] ICPUSDT 처리 중...
# [166/402] ARUSDT 처리 중...
# [167/402] MASKUSDT 처리 중...
# [168/402] LPTUSDT 처리 중...
# [169/402] XVGUSDT 처리 중...
# [170/402] ATAUSDT 처리 중...
# [171/402] GTCUSDT 처리 중...
# [172/402] PHAUSDT 처리 중...
# [173/402] MLNUSDT 처리 중...
# [174/402] DEXEUSDT 처리 중...
# [175/402] C98USDT 처리 중...
# [176/402] QNTUSDT 처리 중...
# [177/402] FLOWUSDT 처리 중...
# [178/402] MINAUSDT 처리 중...
# [179/402] RAYUSDT 처리 중...
# [180/402] FARMUSDT 처리 중...
# [181/402] ALPACAUSDT 처리 중...
# [182/402] QUICKUSDT 처리 중...
# [183/402] MBOXUSDT 처리 중...
# [184/402] REQUSDT 처리 중...
# [185/402] GHSTUSDT 처리 중...
# [186/402] WAXPUSDT 처리 중...
# [187/402] GNOUSDT 처리 중...
# [188/402] XECUSDT 처리 중...
# [189/402] ELFUSDT 처리 중...
# [190/402] DYDXUSDT 처리 중...
# [191/402] IDEXUSDT 처리 중...
# [192/402] VIDTUSDT 처리 중...
# [193/402] USDPUSDT 처리 중...
# [194/402] GALAUSDT 처리 중...
# [195/402] ILVUSDT 처리 중...
# [196/402] YGGUSDT 처리 중...
# [197/402] SYSUSDT 처리 중...
# [198/402] DFUSDT 처리 중...
# [199/402] FIDAUSDT 처리 중...
# [200/402] AGLDUSDT 처리 중...
# [201/402] RADUSDT 처리 중...
# [202/402] BETAUSDT 처리 중...
# [203/402] RAREUSDT 처리 중...
# [204/402] LAZIOUSDT 처리 중...
# [205/402] CHESSUSDT 처리 중...
# [206/402] ADXUSDT 처리 중...
# [207/402] AUCTIONUSDT 처리 중...
# [208/402] MOVRUSDT 처리 중...
# [209/402] CITYUSDT 처리 중...
# [210/402] ENSUSDT 처리 중...
# [211/402] QIUSDT 처리 중...
# [212/402] PORTOUSDT 처리 중...
# [213/402] POWRUSDT 처리 중...
# [214/402] JASMYUSDT 처리 중...
# [215/402] AMPUSDT 처리 중...
# [216/402] PYRUSDT 처리 중...
# [217/402] ALCXUSDT 처리 중...
# [218/402] SANTOSUSDT 처리 중...
# [219/402] BICOUSDT 처리 중...
# [220/402] FLUXUSDT 처리 중...
# [221/402] FXSUSDT 처리 중...
# [222/402] VOXELUSDT 처리 중...
# [223/402] HIGHUSDT 처리 중...
# [224/402] CVXUSDT 처리 중...
# [225/402] PEOPLEUSDT 처리 중...
# [226/402] SPELLUSDT 처리 중...
# [227/402] JOEUSDT 처리 중...
# [228/402] ACHUSDT 처리 중...
# [229/402] IMXUSDT 처리 중...
# [230/402] GLMRUSDT 처리 중...
# [231/402] LOKAUSDT 처리 중...
# [232/402] SCRTUSDT 처리 중...
# [233/402] API3USDT 처리 중...
# [234/402] BTTCUSDT 처리 중...
# [235/402] ACAUSDT 처리 중...
# [236/402] XNOUSDT 처리 중...
# [237/402] WOOUSDT 처리 중...
# [238/402] ALPINEUSDT 처리 중...
# [239/402] TUSDT 처리 중...
# [240/402] ASTRUSDT 처리 중...
# [241/402] GMTUSDT 처리 중...
# [242/402] KDAUSDT 처리 중...
# [243/402] APEUSDT 처리 중...
# [244/402] BSWUSDT 처리 중...
# [245/402] BIFIUSDT 처리 중...
# [246/402] STEEMUSDT 처리 중...
# [247/402] NEXOUSDT 처리 중...
# [248/402] REIUSDT 처리 중...
# [249/402] LDOUSDT 처리 중...
# [250/402] OPUSDT 처리 중...
# [251/402] LEVERUSDT 처리 중...
# [252/402] STGUSDT 처리 중...
# [253/402] LUNCUSDT 처리 중...
# [254/402] GMXUSDT 처리 중...
# [255/402] POLYXUSDT 처리 중...
# [256/402] APTUSDT 처리 중...
# [257/402] OSMOUSDT 처리 중...
# [258/402] HFTUSDT 처리 중...
# [259/402] PHBUSDT 처리 중...
# [260/402] HOOKUSDT 처리 중...
# [261/402] MAGICUSDT 처리 중...
# [262/402] HIFIUSDT 처리 중...
# [263/402] RPLUSDT 처리 중...
# [264/402] PROSUSDT 처리 중...
# [265/402] GNSUSDT 처리 중...
# [266/402] SYNUSDT 처리 중...
# [267/402] VIBUSDT 처리 중...
# [268/402] SSVUSDT 처리 중...
# [269/402] LQTYUSDT 처리 중...
# [270/402] USTCUSDT 처리 중...
# [271/402] GASUSDT 처리 중...
# [272/402] GLMUSDT 처리 중...
# [273/402] PROMUSDT 처리 중...
# [274/402] QKCUSDT 처리 중...
# [275/402] UFTUSDT 처리 중...
# [276/402] IDUSDT 처리 중...
# [277/402] ARBUSDT 처리 중...
# [278/402] RDNTUSDT 처리 중...
# [279/402] WBTCUSDT 처리 중...
# [280/402] EDUUSDT 처리 중...
# [281/402] SUIUSDT 처리 중...
# [282/402] PEPEUSDT 처리 중...
# [283/402] FLOKIUSDT 처리 중...
# [284/402] SNTUSDT 처리 중...
# [285/402] MAVUSDT 처리 중...
# [286/402] PENDLEUSDT 처리 중...
# [287/402] ARKMUSDT 처리 중...
# [288/402] WBETHUSDT 처리 중...
# [289/402] WLDUSDT 처리 중...
# [290/402] FDUSDUSDT 처리 중...
# [291/402] SEIUSDT 처리 중...
# [292/402] CYBERUSDT 처리 중...
# [293/402] ARKUSDT 처리 중...
# [294/402] CREAMUSDT 처리 중...
# [295/402] IQUSDT 처리 중...
# [296/402] NTRNUSDT 처리 중...
# [297/402] TIAUSDT 처리 중...
# [298/402] MEMEUSDT 처리 중...
# [299/402] ORDIUSDT 처리 중...
# [300/402] BEAMXUSDT 처리 중...
# [301/402] PIVXUSDT 처리 중...
# [302/402] VICUSDT 처리 중...
# [303/402] BLURUSDT 처리 중...
# [304/402] VANRYUSDT 처리 중...
# [305/402] AEURUSDT 처리 중...
# [306/402] JTOUSDT 처리 중...
# [307/402] 1000SATSUSDT 처리 중...
# [308/402] BONKUSDT 처리 중...
# [309/402] ACEUSDT 처리 중...
# [310/402] NFPUSDT 처리 중...
# [311/402] AIUSDT 처리 중...
# [312/402] XAIUSDT 처리 중...
# [313/402] MANTAUSDT 처리 중...
# [314/402] ALTUSDT 처리 중...
# [315/402] JUPUSDT 처리 중...
# [316/402] PYTHUSDT 처리 중...
# [317/402] RONINUSDT 처리 중...
# [318/402] DYMUSDT 처리 중...
# [319/402] PIXELUSDT 처리 중...
# [320/402] STRKUSDT 처리 중...
# [321/402] PORTALUSDT 처리 중...
# [322/402] PDAUSDT 처리 중...
# [323/402] AXLUSDT 처리 중...
# [324/402] WIFUSDT 처리 중...
# [325/402] METISUSDT 처리 중...
# [326/402] AEVOUSDT 처리 중...
# [327/402] BOMEUSDT 처리 중...
# [328/402] ETHFIUSDT 처리 중...
# [329/402] ENAUSDT 처리 중...
# [330/402] WUSDT 처리 중...
# [331/402] TNSRUSDT 처리 중...
# [332/402] SAGAUSDT 처리 중...
# [333/402] TAOUSDT 처리 중...
# [334/402] OMNIUSDT 처리 중...
# [335/402] REZUSDT 처리 중...
# [336/402] BBUSDT 처리 중...
# [337/402] NOTUSDT 처리 중...
# [338/402] IOUSDT 처리 중...
# [339/402] ZKUSDT 처리 중...
# [340/402] LISTAUSDT 처리 중...
# [341/402] ZROUSDT 처리 중...
# [342/402] GUSDT 처리 중...
# [343/402] BANANAUSDT 처리 중...
# [344/402] RENDERUSDT 처리 중...
# [345/402] TONUSDT 처리 중...
# [346/402] DOGSUSDT 처리 중...
# [347/402] EURIUSDT 처리 중...
# [348/402] SLFUSDT 처리 중...
# [349/402] POLUSDT 처리 중...
# [350/402] NEIROUSDT 처리 중...
# [351/402] TURBOUSDT 처리 중...
# [352/402] 1MBABYDOGEUSDT 처리 중...
# [353/402] CATIUSDT 처리 중...
# [354/402] HMSTRUSDT 처리 중...
# [355/402] EIGENUSDT 처리 중...
# [356/402] SCRUSDT 처리 중...
# [357/402] BNSOLUSDT 처리 중...
# [358/402] LUMIAUSDT 처리 중...
# [359/402] KAIAUSDT 처리 중...
# [360/402] COWUSDT 처리 중...
# [361/402] CETUSUSDT 처리 중...
# [362/402] PNUTUSDT 처리 중...
# [363/402] ACTUSDT 처리 중...
# [364/402] USUALUSDT 처리 중...
# [365/402] THEUSDT 처리 중...
# [366/402] ACXUSDT 처리 중...
# [367/402] ORCAUSDT 처리 중...
# [368/402] MOVEUSDT 처리 중...
# [369/402] MEUSDT 처리 중...
# [370/402] VELODROMEUSDT 처리 중...
# [371/402] VANAUSDT 처리 중...
# [372/402] 1000CATUSDT 처리 중...
# [373/402] PENGUUSDT 처리 중...
# [374/402] BIOUSDT 처리 중...
# [375/402] DUSDT 처리 중...
# [376/402] AIXBTUSDT 처리 중...
# [377/402] CGPTUSDT 처리 중...
# [378/402] COOKIEUSDT 처리 중...
# [379/402] SUSDT 처리 중...
# [380/402] SOLVUSDT 처리 중...
# [381/402] TRUMPUSDT 처리 중...
# [382/402] ANIMEUSDT 처리 중...
# [383/402] BERAUSDT 처리 중...
# [384/402] 1000CHEEMSUSDT 처리 중...
# [385/402] TSTUSDT 처리 중...
# [386/402] LAYERUSDT 처리 중...
# [387/402] HEIUSDT 처리 중...
# [388/402] KAITOUSDT 처리 중...
# [389/402] SHELLUSDT 처리 중...
# [390/402] REDUSDT 처리 중...
# [391/402] GPSUSDT 처리 중...
# [392/402] EPICUSDT 처리 중...
# [393/402] BMTUSDT 처리 중...
# [394/402] FORMUSDT 처리 중...
# [395/402] XUSDUSDT 처리 중...
# [396/402] NILUSDT 처리 중...
# [397/402] PARTIUSDT 처리 중...
# [398/402] MUBARAKUSDT 처리 중...
# [399/402] TUTUSDT 처리 중...
# [400/402] BROCCOLI714USDT 처리 중...
# [401/402] BANANAS31USDT 처리 중...
# [402/402] GUNUSDT 처리 중...

# %%
#결과
spot_df
# Out:
#              BTCUSDT  ETHUSDT  BNBUSDT  NEOUSDT  LTCUSDT  QTUMUSDT  ADAUSDT  \
# timestamp
# 2017-08-17   4285.08   302.00      NaN      NaN      NaN       NaN      NaN
# 2017-08-18   4108.37   293.96      NaN      NaN      NaN       NaN      NaN
# 2017-08-19   4139.98   290.91      NaN      NaN      NaN       NaN      NaN
# 2017-08-20   4086.29   299.10      NaN      NaN      NaN       NaN      NaN
# 2017-08-21   4016.00   323.29      NaN      NaN      NaN       NaN      NaN
# ...              ...      ...      ...      ...      ...       ...      ...
# 2025-04-04  83889.87  1816.87   597.71     4.84    84.41     1.884   0.6603
# 2025-04-05  83537.99  1806.01   593.13     4.76    82.67     1.878   0.6547
# 2025-04-06  78430.00  1580.76   555.54     4.73    70.62     1.726   0.5737
# 2025-04-07  79163.24  1553.04   554.60     4.79    70.99     1.733   0.5864
# 2025-04-08  78951.99  1569.93   557.90     4.92    71.89     1.737   0.5857
#
#             XRPUSDT  EOSUSDT  TUSDUSDT  ...  BMTUSDT  FORMUSDT  XUSDUSDT  \
# timestamp                               ...
# 2017-08-17      NaN      NaN       NaN  ...      NaN       NaN       NaN
# 2017-08-18      NaN      NaN       NaN  ...      NaN       NaN       NaN
# 2017-08-19      NaN      NaN       NaN  ...      NaN       NaN       NaN
# 2017-08-20      NaN      NaN       NaN  ...      NaN       NaN       NaN
# 2017-08-21      NaN      NaN       NaN  ...      NaN       NaN       NaN
# ...             ...      ...       ...  ...      ...       ...       ...
# 2025-04-04   2.1302   0.7824    0.9990  ...   0.0916    2.1729    1.0001
# 2025-04-05   2.1442   0.7509    0.9990  ...   0.0961    2.1758    1.0002
# 2025-04-06   1.9218   0.7168    0.9984  ...   0.0875    1.9181    1.0001
# 2025-04-07   1.8987   0.7688    0.9987  ...   0.0830    1.9854    1.0003
# 2025-04-08   1.8836   0.7277    0.9987  ...   0.0790    1.9477    1.0001
#
#             NILUSDT  PARTIUSDT  MUBARAKUSDT  TUTUSDT  BROCCOLI714USDT  \
# timestamp
# 2017-08-17      NaN        NaN          NaN      NaN              NaN
# 2017-08-18      NaN        NaN          NaN      NaN              NaN
# 2017-08-19      NaN        NaN          NaN      NaN              NaN
# 2017-08-20      NaN        NaN          NaN      NaN              NaN
# 2017-08-21      NaN        NaN          NaN      NaN              NaN
# ...             ...        ...          ...      ...              ...
# 2025-04-04    0.427     0.1884       0.0387  0.02257          0.02855
# 2025-04-05    0.422     0.1713       0.0381  0.02392          0.03244
# 2025-04-06    0.443     0.1673       0.0397  0.02479          0.02852
# 2025-04-07    0.433     0.1760       0.0388  0.02658          0.02806
# 2025-04-08    0.408     0.1654       0.0353  0.02678          0.02755
#
#             BANANAS31USDT  GUNUSDT
# timestamp
# 2017-08-17            NaN      NaN
# 2017-08-18            NaN      NaN
# 2017-08-19            NaN      NaN
# 2017-08-20            NaN      NaN
# 2017-08-21            NaN      NaN
# ...                   ...      ...
# 2025-04-04       0.005586  0.04162
# 2025-04-05       0.005789  0.05600
# 2025-04-06       0.005950  0.05703
# 2025-04-07       0.005832  0.05336
# 2025-04-08       0.005237  0.04590
#
# [2792 rows x 402 columns]

# %%
#parquet or execl 변환
spot_df.to_parquet("Spot_17_25.parquet", engine='pyarrow')
spot_df.to_excel('Spot_17_25.xlsx',index = True )
